# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2024-03-07 16:18:36.778104: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-07 16:18:36.778163: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-07 16:18:36.779871: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-07 16:18:36.789439: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-07 16:18:37.978321: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df = pd.read_csv('energy_antananarivo_cleaned.csv',index_col='date_dep_dmd',parse_dates=True)

# %%
df = df.drop('tot_energy', axis=1)

# %% [markdown]
# ## Répartition Entraînement / Test

# %%
# Créer des ensembles de train et de test
train_df, test_df = train_test_split(df, test_size=0.1, shuffle=False)

# %% [markdown]
# ## Mise à l'échelle des données

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(train_df)
# Out:
# MinMaxScaler()

# %%
scaled_train = scaler.transform(train_df)
scaled_test = scaler.transform(test_df)

# %%
## Générateur de séries temporelles
length = 12
n_features=1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=length, batch_size=1)

# %% [markdown]
# ## Création du modèle avec LSTM

# %%
# définir le modèle
model = Sequential()
model.add(LSTM(75, input_shape=(length, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
validation_generator = TimeseriesGenerator(scaled_test, scaled_test, length=length, batch_size=1)
early_stop = EarlyStopping(monitor='val_loss',patience=2)
model.fit(generator,epochs=10, validation_data=validation_generator, callbacks=[early_stop])
# Out:
# Epoch 1/10
# 247/247 [==============================] - 7s 14ms/step - loss: 0.0166 - val_loss: 0.0093
# Epoch 2/10
# 247/247 [==============================] - 2s 8ms/step - loss: 0.0083 - val_loss: 0.0136
# Epoch 3/10
# 247/247 [==============================] - 2s 7ms/step - loss: 0.0065 - val_loss: 0.0046
# Epoch 4/10
# 247/247 [==============================] - 2s 7ms/step - loss: 0.0066 - val_loss: 0.0166
# Epoch 5/10
# 247/247 [==============================] - 2s 7ms/step - loss: 0.0062 - val_loss: 0.0250

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Évaluation sur les données Test

# %%
test_predictions = []

first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(len(test_df)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred) 
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 1s 785ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
true_predictions = scaler.inverse_transform(test_predictions)
test_df['LSTM Predictions'] = true_predictions
np.sqrt(mean_squared_error(test_df['tot_nb_dmd'],test_df['LSTM Predictions']))
# Out:
# 907.9657216614393

# %%
test_df.plot()
# Out:
# <Axes: xlabel='date_dep_dmd'>

# %% [markdown]
# ## Re-entrainement et Prévisions

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df)

# %%
length = 12 # Longueur des séquences de sortie (en nombre de pas temporel)
generator = TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
# Modèle LSTM
model = Sequential()
model.add(LSTM(75, input_shape=(length, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

validation_generator = TimeseriesGenerator(scaled_test, scaled_test, length=length, batch_size=1)
early_stop = EarlyStopping(monitor='val_loss',patience=2)
model.fit(generator,epochs=10, validation_data=validation_generator, callbacks=[early_stop])
# Out:
# Epoch 1/10
# 276/276 [==============================] - 7s 11ms/step - loss: 0.0135 - val_loss: 0.0061
# Epoch 2/10
# 276/276 [==============================] - 2s 7ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 3/10
# 276/276 [==============================] - 2s 7ms/step - loss: 0.0062 - val_loss: 0.0047
# Epoch 4/10
# 276/276 [==============================] - 2s 7ms/step - loss: 0.0062 - val_loss: 0.0074
# Epoch 5/10
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0054 - val_loss: 0.0088

# %%
forecast = []
periods = 12
first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    current_pred = model.predict(current_batch)[0]
    forecast.append(current_pred) 
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 1s 931ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
forecast = full_scaler.inverse_transform(forecast)

# %% [markdown]
# ## Création d'un nouvel index TimeStamp avec Pandas

# %%
forecast_index = pd.date_range(start='2023-12-01',periods=periods,freq='MS')
forecast_df = pd.DataFrame(data=forecast,index=forecast_index,
                           columns=['Forecast'])

# %%
forecast_df
# Out:
#                Forecast
# 2023-12-01  3184.295108
# 2024-01-01  3201.256243
# 2024-02-01  3208.094796
# 2024-03-01  3213.894298
# 2024-04-01  3216.570218
# 2024-05-01  3226.756536
# 2024-06-01  3238.400915
# 2024-07-01  3244.183109
# 2024-08-01  3271.336175
# 2024-09-01  3299.013854
# 2024-10-01  3329.436683
# 2024-11-01  3353.905175

# %%
forecast_df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Unification des graphiques avec Pandas

# %%
ax = df.plot()
forecast_df.plot(ax=ax)
# Out:
# <Axes: xlabel='date_dep_dmd'>

# %%
ax = df.plot()
forecast_df.plot(ax=ax)
plt.xlim('2020-01-01','2024-11-01')
# Out:
# (600.0, 658.0)

# %% [markdown]
# ## Calcul de rmse

# %%
np.sqrt(mean_squared_error(test_df['tot_nb_dmd'],test_df['LSTM Predictions']))
# Out:
# 907.9657216614393

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calcul des mesures de performance du modèle sur l'ensemble d'entrainement
# train_mae = mean_absolute_error(train_df, train_pred)
# train_mse = mean_squared_error(train_df, train_pred)
# train_rmse = mean_squared_error(train_df, train_pred, squared=False)
# train_r2 = r2_score(train, train_pred)

# Calcul des mesures de performance sur l'ensemble de test
test_mae = mean_absolute_error(test_df['tot_nb_dmd'], true_predictions)
test_mse = mean_squared_error(test_df['tot_nb_dmd'], true_predictions)
test_rmse = mean_squared_error(test_df['tot_nb_dmd'], true_predictions, squared=False)
test_r2 = r2_score(test_df['tot_nb_dmd'], true_predictions)

# Création d'un Dataframe pour afficher les mesures de performance
perf_df = pd.DataFrame({
    'Métriques:': ['MAE', 'MSE', 'RMSE', 'R²'],
#     'Ensemble d\'entrainenemt:': [train_mae, train_mse, train_rmse, train_r2],
    'Ensemble de test:': [test_mae, test_mse, test_rmse, test_r2]
})

# %%
perf_df
# Out:
#   Métriques:  Ensemble de test:
# 0        MAE         849.900785
# 1        MSE      824401.751712
# 2       RMSE         907.965722
# 3         R²         -43.229921
