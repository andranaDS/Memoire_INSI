# %% [markdown]
# **Tâche : Importation des bibliothèques de base**

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM, SimpleRNN
# Out:
# 2024-03-07 16:47:23.062517: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-07 16:47:23.062561: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-07 16:47:23.064465: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-07 16:47:23.074784: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-07 16:47:24.387178: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df = pd.read_csv('energy_antananarivo_cleaned.csv',index_col='date_dep_dmd',parse_dates=True)

# %%
df.head()
# Out:
#               tot_nb_dmd  tot_energy
# date_dep_dmd
# 2000-01-01          1525  779.932667
# 2000-02-01          1526  745.500000
# 2000-03-01          1549  728.000000
# 2000-04-01          1523  624.500000
# 2000-05-01          1461  614.067333

# %%
df = df.drop('tot_energy', axis=1)

# %% [markdown]
# **Tâche : Traçage des séries temporelles**

# %%
df.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='date_dep_dmd'>

# %% [markdown]
# ## Répartition Entraînement / Test

# %% [markdown]
# **Tâche : Définition de la longueur (taille) du dataset**

# %%
# Créer des ensembles de train et de test
train_df, test_df = train_test_split(df, test_size=0.15, shuffle=False)

# Afficher les tailles des ensembles
print("Taille de l'ensemble d'entraînement :", len(train_df))
print("Taille de l'ensemble de test :", len(test_df))
# Out:
# Taille de l'ensemble d'entraînement : 244
# Taille de l'ensemble de test : 44

# %% [markdown]
# ## Mise à l'échelle des données

# %% [markdown]
# **Tâche : Utilisation de la classe MinMaxScaler pour mettre à l'échelle les ensembles de données d'entraînement et de test dans leurs versions mises à l'échelle.**

# %%
scaler = MinMaxScaler()

# %%
# Adapter uniquement aux données d'entraînement, sinon nous trichons en supposant des informations sur les données test
scaler.fit(train_df)
# Out:
# MinMaxScaler()

# %%
scaled_train = scaler.transform(train_df)
scaled_test = scaler.transform(test_df)

# %% [markdown]
# ## Générateur de séries temporelles
#
# **Tâche : Création d'un objet TimeSeriesGenerator qui se base sur les données scaled_train. La longueur du batch doit être au minimum de 12 pour saisir une saisonnalité d'une année complète.**

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length = 12
n_features=1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=length, batch_size=1)

# %% [markdown]
# ## Création du modèle avec Simple RNN
#
# **Tâche : Création d'un modèle séquentiel de Keras avec des neurones (units).**

# %%
# définir le modèle
model = Sequential()
model.add(SimpleRNN(75, input_shape=(length, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 75)                5775
#
#  dense (Dense)               (None, 1)                 76
#
# =================================================================
# Total params: 5851 (22.86 KB)
# Trainable params: 5851 (22.86 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# ajustement du modèle
model.fit(generator,epochs=5)
# Out:
# Epoch 1/5
# 232/232 [==============================] - 2s 3ms/step - loss: 0.0126
# Epoch 2/5
# 232/232 [==============================] - 1s 4ms/step - loss: 0.0030
# Epoch 3/5
# 232/232 [==============================] - 1s 3ms/step - loss: 0.0024
# Epoch 4/5
# 232/232 [==============================] - 1s 4ms/step - loss: 0.0028
# Epoch 5/5
# 232/232 [==============================] - 1s 3ms/step - loss: 0.0024

# %% [markdown]
# **Tâche : Traçage l'historique des pertes survenues pendant l'entraînement.**

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Évaluation sur les données Test
#
# **Tâche : Prédictions pour la gamme de données de test (les 12 derniers mois de l'ensemble des données).**

# %%
test_predictions = []

first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(len(test_df)):
    
    # obtenir la prédiction avec 1 timestamp d'avance ([0] pour ne saisir que le nombre au lieu de [array])
    current_pred = model.predict(current_batch)[0]
    
    # stocker la prédiction
    test_predictions.append(current_pred) 
    
    # mise à jour du batch pour inclure maintenant la prédiction et supprimer la première valeur
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
test_df['Simple RNN Predictions'] = true_predictions

# %% [markdown]
# **Tâche : Calcul de RMSE.**

# %%
rmse = np.sqrt(mean_squared_error(test_df['tot_nb_dmd'],test_df['Simple RNN Predictions']))
rmse
# Out:
# 323.79882228308674

# %% [markdown]
# **Tâche : Traçage vos prédictions en fonction des valeurs réels (et vrais) du test.**

# %%
test_df.plot()
# Out:
# <Axes: xlabel='date_dep_dmd'>

# %%
df.describe()
# Out:
#         tot_nb_dmd
# count   288.000000
# mean   2230.541667
# std     498.578423
# min    1241.000000
# 25%    1809.250000
# 50%    2225.000000
# 75%    2641.250000
# max    3203.000000

# %% [markdown]
# # Comparaison avec LSTM
#
# ### Création du modèle avec LSTM

# %%
model_lstm = Sequential()
model_lstm.add(LSTM(75, input_shape=(length, n_features)))
model_lstm.add(Dense(1))
model_lstm.compile(optimizer='adam', loss='mse')

# %%
validation_generator = TimeseriesGenerator(scaled_test, scaled_test, length=length, batch_size=1)
early_stop = EarlyStopping(monitor='val_loss', patience=2)

model_lstm.fit(generator,epochs=15, validation_data=validation_generator, callbacks=[early_stop])
# Out:
# Epoch 1/15
# 232/232 [==============================] - 6s 11ms/step - loss: 0.0204 - val_loss: 0.0122
# Epoch 2/15
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0088 - val_loss: 0.0226
# Epoch 3/15
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0083 - val_loss: 0.0073
# Epoch 4/15
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0076 - val_loss: 0.0073
# Epoch 5/15
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0077 - val_loss: 0.0053
# Epoch 6/15
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0069 - val_loss: 0.0069
# Epoch 7/15
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0060 - val_loss: 0.0076

# %%
losses_lstm = pd.DataFrame(model_lstm.history.history)
losses_lstm.plot()
# Out:
# <Axes: >

# %%
test_lstm_predictions = []

first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(len(test_df)):
    current_pred = model.predict(current_batch)[0]
    test_lstm_predictions.append(current_pred) 
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
true_lstm_predictions = scaler.inverse_transform(test_lstm_predictions)
test_df['LSTM Predictions'] = true_lstm_predictions
rmse = np.sqrt(mean_squared_error(test_df['tot_nb_dmd'],test_df['LSTM Predictions']))
rmse
# Out:
# 323.79882228308674

# %%
test_df.plot(figsize=(12,8), subplots=True)
# Out:
# array([<Axes: xlabel='date_dep_dmd'>, <Axes: xlabel='date_dep_dmd'>,
#        <Axes: xlabel='date_dep_dmd'>], dtype=object)

# %% [markdown]
# D'après le graphe, les algorithmes LSTM & Simple RNN produisent exactement la même prédiction. Donc on peut choisir, comme algorithme, entre les deux. Cependant, LSTM est beaucoup plus sensible aux **surapprentissageset aux sous apprentissages** par rapport à algorithme de RNN simple. D'autant plus que les données utilisées sont très simple(une seule feature). En consequent, on va choisir l'algorithme de RNN simple dans la suite du travail.

# %% [markdown]
# ## Re-entrainement et Prévisions avec l'agorithme RNN simple
# Prévisions dans un intervalle inconnu. Nous devrions d'abord utiliser toutes nos données, puisque nous faisons maintenant des prévisions !

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df)

# %%
# Modèle LSTM
forcast_model = Sequential()
forcast_model.add(SimpleRNN(75, input_shape=(length, n_features)))
forcast_model.add(Dense(1))
forcast_model.compile(optimizer='adam', loss='mse')
forcast_model.fit(generator,epochs=4)
# Out:
# Epoch 1/4
# 232/232 [==============================] - 3s 3ms/step - loss: 0.0134
# Epoch 2/4
# 232/232 [==============================] - 1s 4ms/step - loss: 0.0030
# Epoch 3/4
# 232/232 [==============================] - 1s 4ms/step - loss: 0.0026
# Epoch 4/4
# 232/232 [==============================] - 1s 3ms/step - loss: 0.0032

# %%
forecast = []

# peridodes: interval de serie temporelle qu'on souhaite prédir. 
# Ici on veut avoir une prévision d'une année et demi, soit 18 mois
periods = 12
first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # obtenir la prédiction avec 1 timestamp d'avance ([0] pour ne saisir que le nombre au lieu de [array])
    current_pred = forcast_model.predict(current_batch)[0]
    
    # stocker la prédiction
    forecast.append(current_pred) 
    
    # mise à jour du batch pour inclure maintenant la prédiction et supprimer la première valeur
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step

# %%
forecast = full_scaler.inverse_transform(forecast)

# %% [markdown]
# ### Création d'un nouvel index TimeStamp avec Pandas

# %%
forecast_index = pd.date_range(start='2023-12-01',periods=periods,freq='MS')

# %%
forecast_df = pd.DataFrame(data=forecast,index=forecast_index,
                           columns=['Forecast'])

# %%
forecast_df
# Out:
#                Forecast
# 2023-12-01  3050.694183
# 2024-01-01  3090.976236
# 2024-02-01  3041.249760
# 2024-03-01  3064.095767
# 2024-04-01  3005.641971
# 2024-05-01  2964.420153
# 2024-06-01  3044.557413
# 2024-07-01  2858.610108
# 2024-08-01  2895.991474
# 2024-09-01  2873.143245
# 2024-10-01  2940.098075
# 2024-11-01  3022.998027

# %%
df.plot()
forecast_df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Unification des graphiques avec Pandas

# %%
ax = df.plot()
forecast_df.plot(ax=ax)
# Out:
# <Axes: xlabel='date_dep_dmd'>

# %%
ax = df.plot()
forecast_df.plot(ax=ax)
plt.xlim('2020-01-01','2024-11-01')
# Out:
# (600.0, 658.0)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calcul des mesures de performance sur l'ensemble de test
test_mae = mean_absolute_error(test_df['tot_nb_dmd'], true_predictions)
test_mse = mean_squared_error(test_df['tot_nb_dmd'], true_predictions)
test_rmse = mean_squared_error(test_df['tot_nb_dmd'], true_predictions, squared=False)
test_r2 = r2_score(test_df['tot_nb_dmd'], true_predictions)

# Création d'un Dataframe pour afficher les mesures de performance
perf_df = pd.DataFrame({
    'Métriques:': ['MAE', 'MSE', 'RMSE', 'R²'],
#     'Ensemble d\'entrainenemt:': [train_mae, train_mse, train_rmse, train_r2],
    'Ensemble de test:': [test_mae, test_mse, test_rmse, test_r2]
})

# %%
perf_df
# Out:
#   Métriques:  Ensemble de test:
# 0        MAE         292.203373
# 1        MSE      104845.677312
# 2       RMSE         323.798822
# 3         R²          -4.022355
