# %%
import pandas as pd

# %%
datas = pd.read_html('https://fr.countryeconomy.com/energie-et-environnement/electricite-consommation/madagascar')[0]
datas
# Out:
#     Date  Production GWh  Consommation GWh  Consommation par habitant kWh
# 0   2021           2.093             1.956                            676
# 1   2020           1.976             1.862                            660
# 2   2019           2.020             1.889                            686
# 3   2018           2.271             2.166                            844
# 4   2017           2.211             2.101                            842
# 5   2016           2.024             1.916                            792
# 6   2015           2.052             1.949                            829
# 7   2014           1.970             1.873                            821
# 8   2013           1.856             1.762                            795
# 9   2012           1.701             1.617                            752
# 10  2011           1.348             1.271                            609
# 11  2010           1.329             1.260                            622
# ...

# %%
datas = datas.sort_values(by='Date', ascending=True)
datas = datas.reset_index(drop=True)
datas
# Out:
#     Date  Production GWh  Consommation GWh  Consommation par habitant kWh
# 0   1980         417.000           388.000                            447
# 1   1981         420.000           391.000                            438
# 2   1982         431.000           401.000                            438
# 3   1983         452.000           420.000                            447
# 4   1984         476.000           443.000                            459
# 5   1985         483.000           449.000                            454
# 6   1986         482.000           448.000                            441
# 7   1987         478.000           445.000                            426
# 8   1988         490.000           456.000                            425
# 9   1989         541.000           503.000                            457
# 10  1990         574.000           534.000                            472
# 11  1991         568.000           528.000                            455
# ...

# %%
datas.to_csv('prod_conso_energy.csv', index=False)
